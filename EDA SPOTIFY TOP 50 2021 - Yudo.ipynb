# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## SOAL
#
# Lakukan EDA
# - Tentukan Problem Business yang ingin di solve
# - Tentukan Goals dari EDA
# - Tentukan Business Question yang ingin di jawab melalui EDA (Miniman 5 Business Question)
# - Cari Dataset yang Relevan dengan Problem Business yang ingin di solve (Tidak Boleh Sama Satu Dengan Yang Lain)
# - Lakukan Exploratory Data Analysist untuk menjawab Buseiness Question - untuk mencapai GOALS
# - Saran dan Rekomendasi sesuai EDA
# - Buat Persentasi : Powerpoint, Canva, dll...
# - Upload ke Github atau Kaggle atau Akun Masing-Masing ==> Judul / Repository ==> Exploratory Data Analysist..... (Sesuai dgn Data Kalian)
# - Perbaiki Markdown di Github sesuaikan dengan EDA-Persentasi (Raedme.md)
#
#
# ## PROSES EKSPLORATORI
# - Ketika Ada Pendapat, harus didukung/berdasarkan data.
# Misal kita cek penjualan :
# - dalam setahun perbulan , ada kenaikan signifikan di bulan juni
# - cek di data , ternyata tidak ada data yang memberikan informasi, apa yang terjadi di bulan juni. maka lakukan riset di luar data ==> Bisa Googling ==> Baca Berita
# - Insight => Terjadi kenaikan di bulan juni karena idul fitri
# source : http://beritasatu/juni-2020/kenaikan-penjualan-ritel
# - Setiap code ada tujuan dan informasi yang didapat dari data.
# - Setiap Line EDA digunakan untuk menjawab Business Question
#
#
# - CARI DATA DI KEGGLE

# %% [markdown]
# ## BUSINESS PROBLEM
#
# - Problem Bisnis pada analisa pada data ini adalah untuk mencari tau parameter yang digunakan dalam menentukan urutan top 50 pada Aplikasi Spotify dan parameter apa saja yang sebaiknya tidak digunakan pada urutan top 50 Spotify

# %% [markdown]
# ## GOALS
#
# - Goals yang diharapkan adalah untuk menentukan urutan TOP 50 Spotify pada tahun selanjutnya
# - Memberikan gambaran kepada artist yang bekerja di dunia musik dengan tujuan untuk mencapai banyaknya pendengar dengan tujuan dapat menjadikan lagu tersebut dapat masuk ke dalam chart yang ada dalam aplikasi Spotify di tahun berikutnya

# %%
df = pd.read_csv('spotify_top50_2021.csv')
df
# Out:
#                                                    id        artist_name  \
# 0                                                   1     Olivia Rodrigo
# 1                                                   2          Lil Nas X
# 2                                                   3      The Kid LAROI
# 3                                                   4     Olivia Rodrigo
# 4                                                   5           Dua Lipa
# 5                                                   6      Justin Bieber
# 6                                                   7           Doja Cat
# 7                                                   8         The Weeknd
# 8                                                   9      Glass Animals
# 9                                                  10           Måneskin
# 10                                                 11        Masked Wolf
# 11                                                 12          Bad Bunny
# ...

# %% [markdown]
# DATASET : https://www.kaggle.com/equinxx/spotify-top-50-songs-in-2021
#
# Dataset info
# Top 50 most listened songs in the world for year 2021 in Spotify. This dataset has 14 descriptive variables about the songs.
#
# Data description
# - Popularity : The higher the value the more popular the song is
# - Danceability : The higher the value, the easier it is to dance to this song
# - Energy : The energy of a song - the higher the value, the more energtic. song
# - Key : the key the track is in. Integers map to pitches using standard Pitch Class notation. E.g. 0 = C, 1 = C♯/D♭, 2 = D, and so on. If no key was detected, the value is -1 (range: -1; 11)
# - Loudness (dB) : The higher the value, the louder the song
# - Mode : indicates the modality (major or minor) of a track, the type of scale from which its melodic content is derived. Major is represented by 1 and minor is 0
# - Speechiness : The higher the value the more spoken word the song contains
# - Acousticness : The higher the value the more acoustic the song is
# - Instrumentalness : the number of vocals in a song. The closer the value to 1.0, the more instrumental the song is
# - Liveness : The higher the value, the more likely the song is a live recording
# - Valence : The higher the value, the more positive mood for the song
# - Tempo : the overall estimated tempo of a track in beats per minute (BPM)
# - Duration : duration of the song in ms
# - Time signature : an estimated time signature. The time signature (meter) is a notational convention to specify how many beats are in each bar (or measure). The time signature ranges from 3 to 7 indicating time signatures of "3/4", to "7/4"
#
# Detailed explanation of features can be found here: https://developer.spotify.com/documentation/web-api/reference/#/operations/get-audio-features
#
# Source
# |
# Top 50 songs of 2021 playlist in Spotify. I would like to thank Spotify for providing this readily accessible data.
# Image source: https://media.pitchfork.com/photos/6012ef11b752509babbe8191/2:1/w_2560%2Cc_limit/Spotify.png

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                50 non-null     object
#  1   artist_name       49 non-null     object
#  2   track_name        49 non-null     object
#  3   track_id          49 non-null     object
#  4   popularity        49 non-null     float64
#  5   danceability      49 non-null     float64
#  6   energy            49 non-null     float64
#  7   key               49 non-null     float64
#  8   loudness          49 non-null     float64
#  9   mode              49 non-null     float64
#  10  speechiness       49 non-null     float64
#  11  acousticness      49 non-null     float64
#  12  instrumentalness  49 non-null     float64
#  13  liveness          49 non-null     float64
#  14  valence           49 non-null     float64
#  15  tempo             49 non-null     float64
# ...

# %%
pd.crosstab(index =[df['id'],df['artist_name'],df['track_name'], df['popularity']],columns = 'Nilai Popularity').reset_index().sort_values(['popularity','artist_name'], ascending=[False, False])
# Out:
# col_0  id        artist_name  \
# 33      4     Olivia Rodrigo
# 5      14         Ed Sheeran
# 36     43           Doja Cat
# 48      9      Glass Animals
# 15     23          Bad Bunny
# 47      8         The Weeknd
# 1      10           Måneskin
# 34     40           Doja Cat
# 31     38  The Neighbourhood
# 22      3      The Kid LAROI
# 0       1     Olivia Rodrigo
# 21     29     Olivia Rodrigo
# 6      15         The Weeknd
# 9      18     Olivia Rodrigo
# 4      13          Lil Nas X
# 11      2          Lil Nas X
# 45      6      Justin Bieber
# 16     24       Harry Styles
# 43      5           Dua Lipa
# 12     20           24kGoldn
# 13     21             Tiësto
# 42     49         Tate McRae
# 17     25              Riton
# 27     34           Måneskin
# 25     32      Lewis Capaldi
# 46      7           Doja Cat
# 24     31      Ariana Grande
# 18     26         Kali Uchis
# 30     37           Doja Cat
# 3      12          Bad Bunny
# 29     36          Bad Bunny
# ...

# %% [markdown]
# ## Business Question
#
# 1. Lagu apa yang memiliki nilai popularitas tertinggi dan terendah dalam data top 50 spotify tahun 2021 ?
#
# Jawaban :
#
# - Tertinggi :
# - Olivia Rodrigo : Good 4 U
# - Ed Sheeran : Bad Habits
# - Doja Cat : Woman
#
# - Terendah :
# - BTS : Dynamite
#
# ## INSIGHT
#
# - Tingkat nilai yang memiliki popularitas tertinggi dengan nilai 95.0 pertama adalah Olivia Rodrigo - Good 4 U, kedua adalah Ed sheeran - Bad Habbits, ketiga adalah Doja Cat - Woman
# - Dari urutan 3 artis yang mendapatkan popularitas dengan nilai 95.0 diambil Olivia Rodrigo - Good 4 U dengan urutan asrtist dan lagu tertinggi
# - Tingkat nilai yang memiliki popularitasi terendah dengan nilai 67.0 adalah BTS - Dynamite
# - penilaian tersebut dapat dilihat dari data spotify top 50 2021
# - Menurut https://www.urbanasia.com/rilis-mv-good-4-u-olivia-rodrigo-trending-di-twitter-U32170 lagu Olivia Rodrigo - Good 4 U menjadi topik hangat di twitter pada saat perilisannya karena memiliki makna dan pesan mendalam, serta dapat menyampaikan pesan dari makna lagu tersebut ke dalam video klip yang dibuat. Penyebaran lagu tersebut dilakukan secara baik di seluruh dunia, mencakup asia, eropa, dan amerika menggunakan digital platform music Spotify dan juga beberapa social media penunjang lainnya seperti Youtube https://www.youtube.com/watch?v=gNi_6U5Pm_o , Twitter https://twitter.com/oliviarodrigo/status/1393190423108243461, Intagram https://www.instagram.com/p/COsqZJarHaT/. Lagu tersebut juga meraih tingkat pertama pendengaran di beberapa negara https://en.wikipedia.org/wiki/Good_4_U
# - Penyebaran lagu BTS - Dynamite sudah mencakup 25 negara besar di seluruh dunia dan pemasaran lagu sukses menjadi debut nomor 1 di Billboard HOT 100 menurut https://en.wikipedia.org/wiki/Dynamite_(BTS_song). Salah satu alasan lagu ini dapat menjadi top 50 di spotify adalah penggunaan bahasa inggris yang menjadi gebrakan baru boy band asal korea selatan ini, penggunaan bahasa korea menjadi salah satu ciri khas dari boyband tersebut https://www.cheatsheet.com/entertainment/justin-bieber-explains-why-dynamite-has-been-such-a-huge-hit-for-bts-in-the-us.html/

# %%
a = df.drop(41)

# %%
a
# Out:
#     id        artist_name                                         track_name  \
# 0    1     Olivia Rodrigo                                    drivers license
# 1    2          Lil Nas X                     MONTERO (Call Me By Your Name)
# 2    3      The Kid LAROI                          STAY (with Justin Bieber)
# 3    4     Olivia Rodrigo                                           good 4 u
# 4    5           Dua Lipa                          Levitating (feat. DaBaby)
# 5    6      Justin Bieber             Peaches (feat. Daniel Caesar & Giveon)
# 6    7           Doja Cat                           Kiss Me More (feat. SZA)
# 7    8         The Weeknd                                    Blinding Lights
# 8    9      Glass Animals                                         Heat Waves
# 9   10           Måneskin                                            Beggin'
# 10  11        Masked Wolf                             Astronaut In The Ocean
# ...

# %% [markdown]
# ## BUSINESS QUESTION
#
# 2. Apa yang akan dilakukan jika menemukan missing values pada dataset TOP 50 Spotify tahun 2021 ?
#
# Jawaban :
#
# Jika ada missing values maka akan dilakukan penghapusan dengan menggunakan syntax drop dengan catatan missing value tersebut tidak berpengaruh dengan data yang lainnya. Di analisa dengan dataset ini dikeluarkan atau melakukan drop pada id 41, karena hanya ada nomor id dan nama artist yang terdaftar pada tabel id dan artist_name, dan jika data di drop tidak berpengaruh terhadap data lainnya

# %%
a['Plays'] =  np.random.randint(49) 
a
# Out:
#     id        artist_name                                         track_name  \
# 0    1     Olivia Rodrigo                                    drivers license
# 1    2          Lil Nas X                     MONTERO (Call Me By Your Name)
# 2    3      The Kid LAROI                          STAY (with Justin Bieber)
# 3    4     Olivia Rodrigo                                           good 4 u
# 4    5           Dua Lipa                          Levitating (feat. DaBaby)
# 5    6      Justin Bieber             Peaches (feat. Daniel Caesar & Giveon)
# 6    7           Doja Cat                           Kiss Me More (feat. SZA)
# 7    8         The Weeknd                                    Blinding Lights
# 8    9      Glass Animals                                         Heat Waves
# 9   10           Måneskin                                            Beggin'
# 10  11        Masked Wolf                             Astronaut In The Ocean
# ...

# %% [markdown]
# ## BUSINESS QUESTION
#
# 3. Apa yang harus dilakukan jika terdapat data tambahan guna menunjang data TOP 50 Spotify 2021 ?
#
# JAWABAN
#
# Langkah yang dilakukan untuk menambah data penunjang adalah dengan cara menambah feature dan data pada data tersebut.
#
# ## INSIGHT
#
# Pada urutan TOP 50 Spotify parameter utama untuk menjadikan suatu peringkat tertinggi dalam lagu diambil berdasarkan parameter plays atau memainkan lagu yang ada di spotify
#
# Source :
# - https://open.spotify.com/playlist/37i9dQZEVXbMDoHDwVN2tF (Global)
# - https://open.spotify.com/playlist/37i9dQZEVXbObFQZ3JLcXt(Indonesia)
# - https://open.spotify.com/playlist/37i9dQZEVXbNBz9cRCSFkY

# %%
a['mode']
# Out:
# 0     1.0
# 1     0.0
# 2     1.0
# 3     1.0
# 4     0.0
# 5     1.0
# 6     1.0
# 7     1.0
# 8     1.0
# 9     0.0
# 10    0.0
# 11    0.0
# 12    0.0
# 13    0.0
# 14    1.0
# 15    1.0
# 16    1.0
# 17    1.0
# 18    0.0
# 19    0.0
# 20    0.0
# 21    0.0
# 22    1.0
# 23    1.0
# 24    1.0
# 25    0.0
# 26    1.0
# 27    1.0
# 28    1.0
# 29    1.0
# 30    1.0
# 31    1.0
# 32    1.0
# 33    1.0
# 34    1.0
# 35    1.0
# 36    1.0
# 37    1.0
# 38    0.0
# 39    1.0
# 40    0.0
# 42    0.0
# 43    0.0
# 44    0.0
# 45    1.0
# 46    1.0
# 47    1.0
# 48    1.0
# 49    0.0
# Name: mode, dtype: float64

# %%
a['mode'].mode()
# Out:
# 0    1.0
# dtype: float64

# %%
sns.countplot(a['mode'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## BUSINESS QUESTION
#
# 4. Berapa Nilai yang sering muncul pada kolom mode ?
#
# JAWABAN
#
# Nilai yang sering muncul pada kolom mode adalah 1.0, di dalam keterangan data 1.0 merupakan tangga nada major.
#
# ## INSIGHT
#
# Pada data ini tangga nada major merupakan tangga nada yang sering muncul pada urutan TOP 50 Spotify 2021, analisanya adalah karena karakter dari penggunaan tanda nada major adalah bersemangat, bergembira. Sebaliknya tangga nada minor lebih memiliki karakter kurang bersemangat dan lebih cenderung bersifat sedih. Source : https://katadata.co.id/intan/berita/61b9682ab10eb/pengertian-nada-dan-jenis-jenisnya

# %%
a['instrumentalness']
# Out:
# 0     0.000014
# 1     0.000000
# 2     0.000000
# 3     0.000000
# 4     0.000000
# 5     0.000000
# 6     0.000089
# 7     0.000095
# 8     0.000007
# 9     0.000000
# 10    0.000000
# 11    0.000052
# 12    0.000000
# 13    0.000028
# 14    0.000012
# 15    0.000000
# 16    0.000000
# 17    0.000006
# 18    0.000196
# 19    0.000000
# 20    0.019200
# 21    0.000000
# 22    0.000000
# 23    0.000000
# 24    0.000132
# 25    0.000000
# 26    0.000000
# 27    0.000001
# 28    0.000000
# 29    0.000070
# 30    0.000000
# 31    0.000000
# 32    0.000000
# 33    0.000000
# 34    0.000000
# 35    0.000000
# 36    0.038200
# 37    0.017700
# 38    0.000000
# 39    0.000000
# 40    0.000000
# 42    0.002940
# 43    0.001220
# 44    0.000008
# 45    0.000311
# 46    0.000011
# 47    0.000000
# 48    0.000000
# 49    0.000000
# Name: instrumentalness, dtype: float64

# %%
plt.figure(figsize=(15,7))
sns.countplot(a['instrumentalness'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
a['instrumentalness'].mean()
# Out:
# 0.0016386330612244895

# %% [markdown]
# ## BUSINESS QUESTION
#
# 5. Berapakah rata-rata suara instrumental pada data TOP 50 Spotify 2021 ?
#
# JAWABAN
#
# Rata-rata dari suara instrumentall pada TOP 50 Spotify 2021 adalah 0.0 ,
#
# ## INSIGHT
#
# Pada keterangan data TOP 50 Spotify 2021 keterangan 0.0 merupakan penilaian dimana vocal lebih dominan dibandingkan dengan instrumental pada sebuah lagu.

# %% [markdown]
# ## SARAN DAN REKOMENDASI
#
# Untuk menjawab Business problem dan mendapatkan goals yang ingin dicapai maka akan diberikan rekomendasi sebagai berikut:
#
# ### GOALS NO 1 :
#
# - Untuk menentukan urutan top 50 spotify pada tahun berikutnya disarankan untuk menggantikan tabel popularity dengan tabel plays, karena pada urutan top 50 spotify parameter utama yang paling berpengaruh adalah banyaknya jumlah plays pada lagu. tidak dilihat dari tingkat popularitas artis. karena akan berpengaruh pada persentasi penggunaan metode. umber tersebut dapat dilihat pada link top 50 spotify itu sendiri yaitu https://open.spotify.com/playlist/37i9dQZEVXbMDoHDwVN2tF
#
# ### GOALS NO 2 :
#
# - Parameter yang sering masuk ke dalam TOP 50 Spotify yang telah dirangkum dari analisa data TOP 50 Spotify 2021 adalah dengan menggunakan tangga nada major, karakter suara vocal yang dominan dibandingkan dengan instrumental. karena dengan menggunakan 2 aspek tersebut menurut analisa dapat mendapatkan jumlah plays pada pengguna aplikasi spotify. alasan tersebut didasarkan oleh tangga nada major sering didengarkan oleh pendengar karena dapat merubah perasaan seseorang menjadi hal yang lebih positif, senang dan semangat dalam menjalankan hari. Source : https://media.neliti.com/media/publications/325047-pengaruh-musik-sebagai-moodboster-mahasi-eb89de46.pdf.
# - Penggunaan karakter suara vocal yang dominan akan menjadi nilai lebih, karena penyampaian makna dari lirik yang telah dibuat menentukan suasana hati para pendengar atau dalam arti lain dapat berpengaruh pada psikologis pendengar https://www.bbc.com/indonesia/vert_fut/2015/10/151002_vert_fut_musik_emosi. Pendengar musik secara umum tidak menyukai musik yang lebih dominan instrumen karena masih mencari "lirik" dalam lagu, kita ambil salah satunya pendengar musik bergenre Classic, karena secara garis besar alasannya adalah musik bergenre classic merupakan musik yang memiliki tingkat kerumitan yang tinggi, yang mana dari alasan ini pendengar musik tersebut lebih banyak didengarkan oleh para pemain musik yang memiliki keahlian yang lebih dengan tujuan bisa memainkan instrumen tersebut dibandingkan dengan pendengar secara umum https://id.quora.com/Mengapa-orang-muda-secara-umum-tidak-suka-mendengarkan-musik-klasik
# - Penambahan Genre pada tabel data dapat menjadikan salah satu informasi untuk para musisi, dimana dapat menjadi insight bagi para musisi jenis genre apa yang sering menjadi langganan pada TOP 50 Spotify.
